# %% [markdown]
# <a href="https://colab.research.google.com/github/prasinator/prasinator/blob/main/run_pharokka_and_phold_and_phynteny.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pharokka + Phold + Phynteny
#
# [pharokka](https://github.com/gbouras13/pharokka) is a rapid standardised annotation tool for bacteriophage genomes and metagenomes. You can read more about pharokka in the [documentation](https://pharokka.readthedocs.io/).
#
# [phold](https://github.com/gbouras13/phold) is a sensitive annotation tool for bacteriophage genomes and metagenomes using protein structural homology. You can read more about phold in the [documentation](https://phold.readthedocs.io/).
#
# phold uses the [ProstT5](https://github.com/mheinzinger/ProstT5) protein language model to translate protein amino acid sequences to the 3Di token alphabet used by [Foldseek](https://github.com/steineggerlab/foldseek). Foldseek is then used to search these against a database of 803k protein structures mostly predicted using [Colabfold](https://github.com/sokrypton/ColabFold).
#
# [phyntney](https://github.com/susiegriggo/Phynteny_transformer) uses phage synteny (the conserved gene order across phages) with a hybrid transformer/LSTM architecture to assign hypothetical phage proteins to a PHROG category.
#
# The tools are best run sequentially, as Pharokka conducts extra annotation steps like tRNA, tmRNA, CRISPR and INPHARED searches that Phold lacks (for now at least). Pharokka will also (rarely) annotate CDS that Phold can miss. Phynteny can then help annotate remaining hypothetical proteins with a PHROG category.
#
# * **Before you start, please make sure you change the runtime to T4 GPU (or any other kind of GPU if you have $$$), otherwise Phold won't be installed properly**
# * To do this, go to the top toolbar, then to Runtime -> Change runtime type -> Hardware accelerator
#
# * To run the cells, press the play button on the left side
# * Cells 1, 2 and 3 install pharokka, phold and phyntney and download the databases/models.
# * Once they have been run, you can re-run Cell 4 (to run Pharokka), Cell 5 (to run Phold) and Cell 6 (to run Phynteny) as many times as you would like

# %%
#@title 1. Install miniforge

#@markdown This cell installs miniforge

# %%bash

set -e

PYTHON_VERSION=$(python3 -c "import sys; print(f'{sys.version_info.major}.{sys.version_info.minor}')")

echo "python version ${PYTHON_VERSION}"

if [ ! -f CONDA_READY ]; then
  echo "installing miniforge"

  # miniforge 25.9.1 introduces some issue - latest as of 7 Nov 2025 - see https://github.com/gbouras13/phold/issues/106
  # issue is fixed if you use the previous release (25.3.1)
  #wget -qnc https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-Linux-x86_64.sh
  wget -qnc https://github.com/conda-forge/miniforge/releases/download/25.3.1-0/Miniforge3-25.3.1-0-Linux-x86_64.sh
  bash Miniforge3-25.3.1-0-Linux-x86_64.sh -bfp /usr/local 2>&1 1>/dev/null
  conda config --set auto_update_conda false
  touch CONDA_READY
fi

pip install --upgrade matplotlib matplotlib-inline
# Out:
# python version 3.12
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/site-packages (3.10.9)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/site-packages (0.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.12/site-packages (from matplotlib-inline) (5.15.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
#@title 2. Install pharokka and phold and phynteny

#@markdown This cell installs pharokka and phold. It will take a few minutes. Please be patient

PHAROKKA_VERSION="1.9.1"
PHOLD_VERSION="1.2.2"
PHYNTENY_VERSION="0.1.3"

# add paths
import sys
sys.path.append("/usr/local/bin")

# Update environment variables for shell usage
import os
os.environ["PATH"] = "/usr/local/bin:" + os.environ["PATH"]

# create envs
# pharokka isn't compatible with Python 3.13 (Google Colab default)
# so it needs a separate env
from pathlib import Path
flag_file = Path("PHAROKKA_PHOLD_PHYNTENY_READY")
if not flag_file.exists():
  # !conda install -y -c bioconda phold=={PHOLD_VERSION} pharokka=={PHAROKKA_VERSION} pytorch=*=cuda* phynteny_transformer=={PHYNTENY_VERSION}
  # Touch the flag file
  flag_file.touch()

# %%
#@title 3. Download pharokka phold databases

#@markdown This cell downloads the pharokka then the phold database. It will take some time (10-15 minutes probably depending on Zenodo's traffic). Please be patient. Perhaps go for a walk or have a coffee or tea.


# %%time

print("Downloading pharokka database. This will take a few minutes. Please be patient :)")
# !install_databases.py -o pharokka_db


print("Downloading phold database. This will take a few minutes. Please be patient :)")
# !phold install -d phold_db -t 8 --foldseek_gpu


print("Downloading phynteny database. This will take a few minutes. Please be patient :)")
# !install_models -o  phynteny_models
# Out:
# Downloading pharokka database. This will take a few minutes. Please be patient :)
# 2026-06-09 09:12:17.956 | INFO     | databases:instantiate_install:124 - Checking Pharokka database installation in pharokka_db.
# 2026-06-09 09:12:17.956 | INFO     | databases:check_db_installation:252 - PHROGs Database file VERSION_1_8_0 is missing.
# 2026-06-09 09:12:17.956 | INFO     | databases:check_db_installation:259 - VFDB Databases are missing.
# 2026-06-09 09:12:17.956 | INFO     | databases:check_db_installation:266 - CARD Databases are missing.
# 2026-06-09 09:12:17.956 | INFO     | databases:check_db_installation:272 - PHROGs Annotation File is missing.
# 2026-06-09 09:12:17.957 | INFO     | databases:check_db_installation:278 - INPHARED Mash Annotation File is missing.
# 2026-06-09 09:12:17.957 | INFO     | databases:check_db_installation:284 - INPHARED Mash Sketch File is missing.
# 2026-06-09 09:12:17.957 | INFO     | databases:instantiate_install:129 - Some Databases are missing.
# 2026-06-09 09:12:17.961 | INFO     | databases:instantiate_install:134 - Downloading Pharokka Databases from https://zenodo.org/record/17110353/files/pharokka_v1.8.0_databases.tar.gz.
#
# 2026-06-09 09:13:37.688 | INFO     | databases:instantiate_install:145 - Database file download OK: a63c485241b900a11989bd1821bfbb09
# 2026-06-09 09:13:37.688 | INFO     | databases:instantiate_install:151 - Extracting DB tarball: file=pharokka_db/pharokka_v1.8.0_databases.tar.gz, output=pharokka_db
# Downloading phold database. This will take a few minutes. Please be patient :)
# 2026-06-09 09:14:04.208 | INFO     | phold:install:1343 - You have specified the phold_db directory to store the Phold database and ProstT5 model
# 2026-06-09 09:14:04.208 | INFO     | phold:install:1355 - Checking that the Rostlab/ProstT5_fp16 ProstT5 model is available in phold_db
# 2026-06-09 09:14:04.212 | INFO     | phold.features.predict_3Di:get_T5_model:125 - Using device: cpu
# 2026-06-09 09:14:04.212 | INFO     | phold.features.predict_3Di:get_T5_model:131 - Loading T5 from: phold_db/Rostlab/ProstT5_fp16
# 2026-06-09 09:14:04.213 | INFO     | phold.features.predict_3Di:get_T5_model:132 - If phold_db/Rostlab/ProstT5_fp16 is not found, it will be downloaded
# 2026-06-09 09:14:04.213 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/refs/main does not exist.
# 2026-06-09 09:14:04.213 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/2c19eb6e3b583f52d34b903b5978d3d30b6b7682 does not exist.
# 2026-06-09 09:14:04.213 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/60fe6bb247c90b8545d7b73820cd796ce6dcbd59 does not exist.
# 2026-06-09 09:14:04.213 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/6fc7be92c58e238f20a6cdea5a87b123a4ad35e2 does not exist.
# 2026-06-09 09:14:04.213 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/74da7b4afcde53faa570114b530c726135bdfcdb813dec3abfb27f9d44db7324 does not exist.
# 2026-06-09 09:14:04.213 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/b1a9ffcef73280cc57f090ad6446b4116b574b6c75d83ccc32778282f7f00855 does not exist.
# 2026-06-09 09:14:04.213 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/e9322396e6e75ecf8da41a9527e24dfa4eeea505 does not exist.
# 2026-06-09 09:14:04.213 | INFO     | phold.features.predict_3Di:get_T5_model:142 - ProstT5 not found. Downloading ProstT5 from Hugging Face
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-06-09 09:15:02.186 | INFO     | phold.features.predict_3Di:get_T5_model:174 - Rostlab/ProstT5_fp16 loaded
# 2026-06-09 09:15:02.421 | INFO     | phold:install:1366 - ProstT5 model downloaded
# 2026-06-09 09:15:02.421 | INFO     | phold.databases.db:install_database:143 - Checking Phold database installation in phold_db.
# 2026-06-09 09:15:02.422 | WARNING  | phold.databases.db:check_db_installation:430 - Phold Database file phold_db/acrs_plddt_over_70_metadata.tsv is missing
# 2026-06-09 09:15:02.422 | WARNING  | phold.databases.db:check_db_installation:439 - Phold Foldseek-GPU Database file phold_db/all_phold_structures_gpu is missing
# 2026-06-09 09:15:02.422 | INFO     | phold.databases.db:install_database:148 - Some Phold databases files are missing
# 2026-06-09 09:15:02.422 | INFO     | phold.databases.db:install_database:158 - Downloading Phold Search DB 1.36M from https://zenodo.org/records/16741548/files/phold_search_db_v_1_0_0.tar.gz
# 2026-06-09 09:15:02.423 | INFO     | phold.utils.external_tools:run_stream:56 - Started running aria2c --dir phold_db --out phold_search_db_v_1_0_0.tar.gz --max-connection-per-server=8 --allow-overwrite=true https://zenodo.org/records/16741548/files/phold_search_db_v_1_0_0.tar.gz ...
#
# 06/09 09:15:02 [NOTICE] Downloading 1 item(s)
# [#05702d 0B/0B CN:1 DL:0B]
# [#05702d 80KiB/1.7GiB(0%) CN:5 DL:282KiB ETA:1h49m26s]
# [#05702d 1.6MiB/1.7GiB(0%) CN:5 DL:1.2MiB ETA:23m50s]
# [#05702d 5.4MiB/1.7GiB(0%) CN:5 DL:2.3MiB ETA:13m3s]
# [#05702d 8.0MiB/1.7GiB(0%) CN:5 DL:2.1MiB ETA:13m43s]
# [#05702d 9.7MiB/1.7GiB(0%) CN:5 DL:1.9MiB ETA:15m25s]
# [#05702d 11MiB/1.7GiB(0%) CN:5 DL:1.7MiB ETA:17m15s]
# [#05702d 23MiB/1.7GiB(1%) CN:5 DL:3.2MiB ETA:9m16s]
# [#05702d 28MiB/1.7GiB(1%) CN:5 DL:3.3MiB ETA:8m49s]
# [#05702d 32MiB/1.7GiB(1%) CN:5 DL:3.4MiB ETA:8m41s]
# [#05702d 36MiB/1.7GiB(2%) CN:5 DL:3.7MiB ETA:7m47s]
# [#05702d 1.7GiB/1.7GiB(99%) CN:1 DL:26MiB]
# [#05702d 1.7GiB/1.7GiB(99%) CN:1 DL:22MiB]
# [#05702d 1.7GiB/1.7GiB(99%) CN:1 DL:18MiB]
# [#05702d 1.7GiB/1.7GiB(99%) CN:1 DL:15MiB]
# [#05702d 1.7GiB/1.7GiB(99%) CN:1 DL:11MiB]
# [#05702d 1.7GiB/1.7GiB(99%) CN:1 DL:4.3MiB ETA:2s]
# [#05702d 1.7GiB/1.7GiB(99%) CN:1 DL:2.0MiB ETA:4s]
# [#05702d 1.7GiB/1.7GiB(99%) CN:1 DL:0.9MiB ETA:8s]
# [#05702d 1.7GiB/1.7GiB(99%) CN:1 DL:1.7MiB]
#
# 06/09 09:16:43 [NOTICE] Download complete: phold_db/phold_search_db_v_1_0_0.tar.gz
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 05702d|OK  |    18MiB/s|phold_db/phold_search_db_v_1_0_0.tar.gz
#
# Status Legend:
# (OK):download completed.
# 2026-06-09 09:16:43.065 | INFO     | phold.utils.external_tools:run_stream:73 - Done running aria2c --dir phold_db --out phold_search_db_v_1_0_0.tar.gz --max-connection-per-server=8 --allow-overwrite=true https://zenodo.org/records/16741548/files/phold_search_db_v_1_0_0.tar.gz
# 2026-06-09 09:16:47.168 | INFO     | phold.databases.db:install_database:171 - Phold database file download OK: ddbe0d94b1d94a392cfeb4ec113f4362
# 2026-06-09 09:16:47.168 | INFO     | phold.databases.db:install_database:177 - Extracting Phold database tarball: file=phold_db/phold_search_db_v_1_0_0.tar.gz, output=phold_db
# 2026-06-09 09:17:16.924 | INFO     | phold.databases.db:install_database:189 - Some Phold database files compatible with Foldseek-GPU are missing
# 2026-06-09 09:17:16.924 | INFO     | phold.databases.db:install_database:192 - Creating them
# 2026-06-09 09:17:16.925 | INFO     | phold.utils.external_tools:run:45 - Started running foldseek makepaddedseqdb phold_db/all_phold_structures phold_db/all_phold_structures_gpu ...
# 2026-06-09 09:17:38.299 | INFO     | phold.utils.external_tools:run:47 - Done running foldseek makepaddedseqdb phold_db/all_phold_structures phold_db/all_phold_structures_gpu
# Downloading phynteny database. This will take a few minutes. Please be patient :)
# /usr/local/lib/python3.12/site-packages/src/install_models.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Creating 'models' subdirectory in specified path
# Downloading Phynteny models to: /content/phynteny_models/models
# 2026-06-09 09:17:42.323 | INFO     | src.install_models:instantiate_install:51 - Model installation directory (absolute path): /content/phynteny_models/models
# 2026-06-09 09:17:42.323 | WARNING  | src.install_models:check_db_installation:93 - Phynteny models are missing.
# 2026-06-09 09:17:42.323 | INFO     | src.install_models:instantiate_install:61 - Some models are missing.
# 2026-06-09 09:17:42.323 | INFO     | src.install_models:get_model_zenodo:325 - Models will be installed to: /content/phynteny_models/models
# 2026-06-09 09:17:42.323 | INFO     | src.install_models:get_model_zenodo:331 - Downloading tarball to: /content/phynteny_models
# 2026-06-09 09:17:42.324 | INFO     | src.install_models:get_model_zenodo:341 - Downloading Phynteny Models from https://zenodo.org/records/17336733/files/phynteny_transformer_models_2025-06-03.tar.gz.
# 2026-06-09 09:17:42.324 | DEBUG    | src.install_models:get_model_zenodo:342 - path
# 2026-06-09 09:17:42.324 | DEBUG    | src.install_models:get_model_zenodo:343 - https://zenodo.org/records/17336733/files/phynteny_transformer_models_2025-06-03.tar.gz
# 2026-06-09 09:17:42.868 | INFO     | src.install_models:download:114 - Downloading file, total size: 222.05 MB
# Progress: 100.0% (222.0/222.0 MB)
# 2026-06-09 09:21:12.098 | INFO     | src.install_models:get_model_zenodo:350 - Phynteny Models tarball download OK: 511358aca216d214b5d7ca7a57fe2250
# 2026-06-09 09:21:12.098 | INFO     | src.install_models:get_model_zenodo:357 - Extracting Phynteny Models tarball: file=phynteny_models/phynteny_transformer_models_2025-06-03.tar.gz, output=/content/phynteny_models/models
# 2026-06-09 09:21:12.098 | INFO     | src.install_models:untar:202 - Path checks: {'tarball_exists': True, 'tarball_readable': True, 'tarball_size': 232831570, 'output_exists': True, 'output_writable': True}
# 2026-06-09 09:21:13.600 | INFO     | src.install_models:untar:218 - Tarball inspection: {'status': 'success', 'file_count': 14, 'top_level_dirs': ['phynteny_transformer_models_2025-06-03'], 'sample_files': ['phynteny_transformer_models_2025-06-03', 'phynteny_transformer_models_2025-06-03/all_calibration_models.pkl', 'phynteny_transformer_models_2025-06-03/calibration_models.pkl', 'phynteny_transformer_models_2025-06-03/category_mapping.pkl', 'phynteny_transformer_models_2025-06-03/fold_10transformer.model']}
# 2026-06-09 09:21:13.601 | INFO     | src.install_models:untar:221 - Starting extraction: phynteny_models/phynteny_transformer_models_2025-06-03.tar.gz to phynteny_models/models
# 2026-06-09 09:21:15.143 | INFO     | src.install_models:untar:225 - Found 14 items in tarball
# 2026-06-09 09:21:15.143 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03
# 2026-06-09 09:21:15.143 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/all_calibration_models.pkl
# 2026-06-09 09:21:15.146 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/calibration_models.pkl
# 2026-06-09 09:21:15.147 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/category_mapping.pkl
# 2026-06-09 09:21:15.147 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_10transformer.model
# 2026-06-09 09:21:15.312 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_1transformer.model
# 2026-06-09 09:21:15.500 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_2transformer.model
# 2026-06-09 09:21:15.664 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_3transformer.model
# 2026-06-09 09:21:15.833 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_4transformer.model
# 2026-06-09 09:21:16.025 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_5transformer.model
# 2026-06-09 09:21:16.217 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_6transformer.model
# 2026-06-09 09:21:16.419 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_7transformer.model
# 2026-06-09 09:21:16.624 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_8transformer.model
# 2026-06-09 09:21:16.808 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_9transformer.model
# 2026-06-09 09:21:16.983 | INFO     | src.install_models:untar:241 - Extraction completed
# 2026-06-09 09:21:16.984 | INFO     | src.install_models:untar:248 - Contents of output directory after extraction: ['phynteny_transformer_models_2025-06-03']
# 2026-06-09 09:21:16.984 | INFO     | src.install_models:untar:265 - Found potential model directories: ['phynteny_transformer_models_2025-06-03']
# 2026-06-09 09:21:16.984 | INFO     | src.install_models:untar:282 - Found 13 files to move from phynteny_models/models/phynteny_transformer_models_2025-06-03 to phynteny_models/models
# 2026-06-09 09:21:16.984 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_5transformer.model to phynteny_models/models/fold_5transformer.model
# 2026-06-09 09:21:16.984 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_7transformer.model to phynteny_models/models/fold_7transformer.model
# 2026-06-09 09:21:16.984 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_10transformer.model to phynteny_models/models/fold_10transformer.model
# 2026-06-09 09:21:16.984 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_3transformer.model to phynteny_models/models/fold_3transformer.model
# 2026-06-09 09:21:16.985 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_9transformer.model to phynteny_models/models/fold_9transformer.model
# 2026-06-09 09:21:16.985 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_2transformer.model to phynteny_models/models/fold_2transformer.model
# 2026-06-09 09:21:16.985 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_8transformer.model to phynteny_models/models/fold_8transformer.model
# 2026-06-09 09:21:16.985 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/calibration_models.pkl to phynteny_models/models/calibration_models.pkl
# 2026-06-09 09:21:16.985 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_4transformer.model to phynteny_models/models/fold_4transformer.model
# 2026-06-09 09:21:16.985 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_6transformer.model to phynteny_models/models/fold_6transformer.model
# 2026-06-09 09:21:16.985 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/all_calibration_models.pkl to phynteny_models/models/all_calibration_models.pkl
# 2026-06-09 09:21:16.985 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_1transformer.model to phynteny_models/models/fold_1transformer.model
# 2026-06-09 09:21:16.985 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/category_mapping.pkl to phynteny_models/models/category_mapping.pkl
# 2026-06-09 09:21:16.985 | INFO     | src.install_models:untar:295 - Successfully moved 13 files to phynteny_models/models
# 2026-06-09 09:21:16.985 | INFO     | src.install_models:untar:299 - Removing temporary directory: phynteny_models/models/phynteny_transformer_models_2025-06-03
# 2026-06-09 09:21:16.986 | INFO     | src.install_models:get_model_zenodo:363 - Keeping tarball at phynteny_models/phynteny_transformer_models_2025-06-03.tar.gz
# 2026-06-09 09:21:16.986 | INFO     | src.install_models:get_model_zenodo:367 - Installed 10 model files
# 2026-06-09 09:21:16.986 | INFO     | src.install_models:get_model_zenodo:372 - Done.
# 2026-06-09 09:21:16.986 | INFO     | src.install_models:instantiate_install:63 - Models successfully downloaded to: /content/phynteny_models/models
#
# Installation Summary:
# ---------------------
# Models directory: /content/phynteny_models/models
# Model files installed: 10
# Confidence dictionary: Installed
#
# When running phynteny_transformer, use:
#   phynteny_transformer -m /content/phynteny_models/models [other options] INPUT_FILE
# CPU times: user 1.29 s, sys: 266 ms, total: 1.55 s
# Wall time: 9min 3s

# %%
#@title 4. Run Pharokka

#@markdown First, upload your phage(s) as a nucleotide input FASTA file

#@markdown Click on the folder icon to the left and use the file upload button.

#@markdown Once it is uploaded, write the file name in the INPUT_FILE field on the right.

#@markdown Then provide a directory for pharokka's output using PHAROKKA_OUT_DIR.
#@markdown The default is 'output_pharokka'.

#@markdown Then type in a gene prediction tool for pharokka.
#@markdown Please choose either 'phanotate', 'prodigal', or 'prodigal-gv'.

#@markdown You can also provide a prefix for your output files with PHAROKKA_PREFIX.
#@markdown If you provide nothing it will default to 'pharokka'.

#@markdown You can also provide a locus tag for your output files.
#@markdown If you provide nothing it will generate a random locus tag.

#@markdown You can click FAST to turn off --fast.
#@markdown By default it is True so that Pharokka runs faster in the Colab environment.

#@markdown You can click META to turn on --meta if you have multiple phages in your input.

#@markdown You can click META_HMM to turn on --meta_hmm.

#@markdown You can click FORCE to overwrite the output directory.
#@markdown This may be useful if your earlier pharokka run has crashed for whatever reason.

#@markdown The results of Pharokka will be in the folder icon on the left hand panel.
#@markdown Additionally, it will be zipped so you can download the whole directory.

#@markdown The file to download is PHAROKKA_OUT_DIR.zip, where PHAROKKA_OUT_DIR is what you provided

#@markdown If you do not see the output directory,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import sys
import subprocess
import zipfile
INPUT_FILE = 'sequence.fasta' #@param {type:"string"}

if os.path.exists(INPUT_FILE):
    print(f"Input file {INPUT_FILE} exists")
else:
    print(f"Error: File {INPUT_FILE} does not exist")
    print(f"Please check the spelling and that you have uploaded it correctly")
    sys.exit(1)

PHAROKKA_OUT_DIR = 'output_pharokka'  #@param {type:"string"}
GENE_PREDICTOR = 'phanotate'  #@param {type:"string"}
allowed_gene_predictors = ['phanotate', 'prodigal', 'prodigal-gv']
# Check if the input parameter is valid
if GENE_PREDICTOR.lower() not in allowed_gene_predictors:
    raise ValueError("Invalid GENE_PREDICTOR. Please choose from: 'phanotate', 'prodigal', 'prodigal-gv'.")

PHAROKKA_PREFIX = 'pharokka'  #@param {type:"string"}
LOCUS_TAG = 'Default'  #@param {type:"string"}
FAST = True  #@param {type:"boolean"}
META = False  #@param {type:"boolean"}
META_HMM = False  #@param {type:"boolean"}
FORCE = True  #@param {type:"boolean"}


# Construct the command
# need to suppress PYTHONWARNINGS for phanotate version handling
command = (
    f'pharokka.py -d pharokka_db -i {INPUT_FILE} -t 4 '
    f'-o {PHAROKKA_OUT_DIR} -p {PHAROKKA_PREFIX} -l {LOCUS_TAG} -g {GENE_PREDICTOR}'
)

if FORCE is True:
  command = f"{command} -f"

if FAST is True:
  command = f"{command} --fast"

if META is True:
  command = f"{command} -m"

if META_HMM is True:
  command = f"{command} --meta_hmm"

# Execute the command
try:
    print("Running pharokka")
    subprocess.run(command, shell=True, check=True)
    print("pharokka completed successfully.")
    print(f"Your output is in {PHAROKKA_OUT_DIR}.")
    print(f"Zipping the output directory so you can download it all in one go.")

    zip_filename = f"{PHAROKKA_OUT_DIR}.zip"

    # Zip the contents of the output directory
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(PHAROKKA_OUT_DIR):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), PHAROKKA_OUT_DIR))
    print(f"Output directory has been zipped to {zip_filename}")


except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
# Out:
# Input file sequence.fasta exists
# Running pharokka
# pharokka completed successfully.
# Your output is in output_pharokka.
# Zipping the output directory so you can download it all in one go.
# Output directory has been zipped to output_pharokka.zip
# CPU times: user 108 ms, sys: 3.3 ms, total: 111 ms
# Wall time: 2min 27s

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#@title 5. Run phold

#@markdown This cell will run phold on the output of cell 3's Pharokka run

#@markdown You do not need to provide any further input files

#@markdown You can now provide a directory for phold's output with PHOLD_OUT_DIR.
#@markdown The default is 'output_phold'.

#@markdown You can also provide a prefix for your output files with PHOLD_PREFIX.
#@markdown If you provide nothing it will default to 'phold'.

#@markdown You can click FORCE to overwrite the output directory with .
#@markdown This may be useful if your earlier phold run has crashed for whatever reason.

#@markdown If your input has multiple phages, you can click SEPARATE.
#@markdown This will output separate GenBank files in the output directory.

#@markdown The results of Phold will be in the folder icon on the left hand panel.
#@markdown Additionally, it will be zipped so you can download the whole directory.

#@markdown The file to download is PHOLD_OUT_DIR.zip, where PHOLD_OUT_DIR is what you provided

#@markdown If you do not see the output directory,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import subprocess
import zipfile

# phold input is pharokka output
PHOLD_INPUT = f"{PHAROKKA_OUT_DIR}/{PHAROKKA_PREFIX}.gbk"
PHOLD_OUT_DIR = 'output_phold'  #@param {type:"string"}
PHOLD_PREFIX = 'phold'  #@param {type:"string"}
FORCE = True  #@param {type:"boolean"}
SEPARATE = False  #@param {type:"boolean"}

# Construct the command
command = f"phold run -i {PHOLD_INPUT} -t 4 -o {PHOLD_OUT_DIR} -p {PHOLD_PREFIX} -d phold_db --foldseek_gpu"

if FORCE is True:
  command = f"{command} -f"
if SEPARATE is True:
  command = f"{command} --separate"


# Execute the command
try:
    print("Running phold")
    subprocess.run(command, shell=True, check=True)
    print("phold completed successfully.")
    print(f"Your output is in {PHOLD_OUT_DIR}.")
    print(f"Zipping the output directory so you can download it all in one go.")

    zip_filename = f"{PHOLD_OUT_DIR}.zip"

    # Zip the contents of the output directory
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(PHOLD_OUT_DIR):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), PHOLD_OUT_DIR))
    print(f"Output directory has been zipped to {zip_filename}")


except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
# Out:
# Running phold
# phold completed successfully.
# Your output is in output_phold.
# Zipping the output directory so you can download it all in one go.
# Output directory has been zipped to output_phold.zip
# CPU times: user 111 ms, sys: 3.44 ms, total: 114 ms
# Wall time: 2min 21s

# %%
#@title 6. Run Phynteny

#@markdown This cell will run phynteny on the output of cell 5's Phold run to predict the function of remaining hypothetical proteins

#@markdown You do not need to provide any further input files

#@markdown You can now provide a directory for phynteny's output with PHYNTENY_OUT_DIR.
#@markdown The default is 'output_phynteny'.

#@markdown You can click FORCE to overwrite the output directory with .
#@markdown This may be useful if your phynteny run has crashed for whatever reason.

#@markdown The results of Phynteny will be in the folder icon on the left hand panel.
#@markdown Additionally, it will be zipped so you can download the whole directory.

#@markdown The file to download is PHYNTENY_OUT_DIR.zip, where PHYNTENY_OUT_DIR is what you provided

#@markdown If you do not see the output directory,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import subprocess
import zipfile

# phynteny input is pharokka output
PHYNTENY_INPUT = f"{PHOLD_OUT_DIR}/{PHOLD_PREFIX}.gbk"
PHYNTENY_OUT_DIR = 'output_phynteny'  #@param {type:"string"}
FORCE = False  #@param {type:"boolean"}

# Construct the command
command = f"phynteny_transformer -m  /content/phynteny_models/models -o {PHYNTENY_OUT_DIR} {PHYNTENY_INPUT}"
if FORCE is True:
  command = f"{command} -f"


# Execute the command
try:
    print("Running phynteny")
    subprocess.run(command, shell=True, check=True)
    print("phynteny completed successfully.")
    print(f"Your output is in {PHYNTENY_OUT_DIR}.")
    print(f"Zipping the output directory so you can download it all in one go.")

    zip_filename = f"{PHYNTENY_OUT_DIR}.zip"

    # Zip the contents of the output directory
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(PHYNTENY_OUT_DIR):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), PHYNTENY_OUT_DIR))
    print(f"Output directory has been zipped to {zip_filename}")


except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
# Out:
# Running phynteny
# phynteny completed successfully.
# Your output is in output_phynteny.
# Zipping the output directory so you can download it all in one go.
# Output directory has been zipped to output_phynteny.zip
# CPU times: user 127 ms, sys: 1.16 ms, total: 128 ms
# Wall time: 1min 20s
